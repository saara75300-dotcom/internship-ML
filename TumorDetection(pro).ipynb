# %% [markdown]
# LogisticRegression(TumorDetection)sangareshwari

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression

# %%
dia = pd.read_csv('/content/drive/MyDrive/Internship/Datasets/tumordata.csv')
dia.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
dia.isnull
# Out:
# <bound method DataFrame.isnull of            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
ind = dia[['radius_mean',
'texture_mean',
'perimeter_mean',
'area_mean',
'smoothness_mean',
'compactness_mean',
'concavity_mean',
'concavepoints_mean',
'symmetry_mean',
'fractal_dimension_mean'
]]
dep = dia['diagnosis']

# %%
Logr = LogisticRegression()
Logr.fit(ind,dep)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
radius_mean = int(input('Enter radius mean: '))
texture_mean  = int(input('Enter texture mean: '))
perimeter_mean = int(input('Enter perimeter mean: '))
area_mean  = int(input('Enter area mean: '))
smoothness_mean  = int(input('Enter smoothness mean: '))
compactness_mean  = int(input('Enter compactness mean: '))
concavity_mean  = int(input('Enter concavity mean: '))
concavepoints_mean  = int(input('Enter concavepoint mean: '))
symmetry_mean  = int(input('Enter symmetry mean: '))
fractal_dimension_mean  = int(input('Enter fractal dimension mean: '))
# Out:
# Enter radius mean: 4
# Enter texture mean: 3
# Enter perimeter mean: 3
# Enter area mean: 3
# Enter smoothness mean: 3
# Enter compactness mean: 4
# Enter concavity mean: 4
# Enter concavepoint mean: 4
# Enter symmetry mean: 4
# Enter fractal dimension mean: 4

# %%
Logr.score(ind,dep)
# Out:
# 0.9121265377855887

# %%
from sklearn.metrics import accuracy_score
pval = Logr.predict(ind)
accuracy_score(dep,pval)
# Out:
# 0.9121265377855887
